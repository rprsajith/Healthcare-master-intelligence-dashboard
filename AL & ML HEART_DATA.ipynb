# %%
2 + 2
# Out:
# 4

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('/content/heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
df.shape
# Out:
# (1025, 14)

# %%
x = df['age']
y = df['sex']
print(x,y)
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 1020    1
# 1021    1
# 1022    1
# 1023    0
# 1024    1
# Name: sex, Length: 1025, dtype: int64

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 1025 artists>

# %%
plt.pie(x,y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7adcadf68670>,
#   <matplotlib.patches.Wedge at 0x7adcadf68550>,
#   <matplotlib.patches.Wedge at 0x7adcadf68f40>,
#   <matplotlib.patches.Wedge at 0x7adcadf692a0>,
#   <matplotlib.patches.Wedge at 0x7adcadf69720>,
#   <matplotlib.patches.Wedge at 0x7adcadf69ba0>,
#   <matplotlib.patches.Wedge at 0x7adcadf6a020>,
#   <matplotlib.patches.Wedge at 0x7adcadf6a4a0>,
#   <matplotlib.patches.Wedge at 0x7adcadf6a920>,
#   <matplotlib.patches.Wedge at 0x7adcadf6ada0>,
#   <matplotlib.patches.Wedge at 0x7adcadf685e0>,
#   <matplotlib.patches.Wedge at 0x7adcadf6b670>,
#   <matplotlib.patches.Wedge at 0x7adcadf6baf0>,
#   <matplotlib.patches.Wedge at 0x7adcadf6bf70>,
#   <matplotlib.patches.Wedge at 0x7adcadda0430>,
#   <matplotlib.patches.Wedge at 0x7adcadda08b0>,
#   <matplotlib.patches.Wedge at 0x7adcadda0d30>,
#   <matplotlib.patches.Wedge at 0x7adcadda11b0>,
#   <matplotlib.patches.Wedge at 0x7adcadda1630>,
#   <matplotlib.patches.Wedge at 0x7adcadda1ab0>,
#   <matplotlib.patches.Wedge at 0x7adcadda1f30>,
#   <matplotlib.patches.Wedge at 0x7adcadda23b0>,
#   <matplotlib.patches.Wedge at 0x7adcadda2830>,
#   <matplotlib.patches.Wedge at 0x7adcadda2cb0>,
#   <matplotlib.patches.Wedge at 0x7adcadda3130>,
#   <matplotlib.patches.Wedge at 0x7adcadda35b0>,
#   <matplotlib.patches.Wedge at 0x7adcadda3a30>,
#   <matplotlib.patches.Wedge at 0x7adcadda3eb0>,
#   <matplotlib.patches.Wedge at 0x7adcadddc370>,
#   <matplotlib.patches.Wedge at 0x7adcadddc7f0>,
#   <matplotlib.patches.Wedge at 0x7adcadddcc70>,
#   <matplotlib.patches.Wedge at 0x7adcadddd0f0>,
#   <matplotlib.patches.Wedge at 0x7adcadddd570>,
#   <matplotlib.patches.Wedge at 0x7adcadddd840>,
#   <matplotlib.patches.Wedge at 0x7adcaddddcc0>,
#   <matplotlib.patches.Wedge at 0x7adcaddde140>,
#   <matplotlib.patches.Wedge at 0x7adcaddde5c0>,
#   <matplotlib.patches.Wedge at 0x7adcadddea40>,
#   <matplotlib.patches.Wedge at 0x7adcadddeec0>,
#   <matplotlib.patches.Wedge at 0x7adcafdf4670>,
#   <matplotlib.patches.Wedge at 0x7adcafdf5a20>,
#   <matplotlib.patches.Wedge at 0x7adcafdf6ce0>,
#   <matplotlib.patches.Wedge at 0x7adcafdf78b0>,
#   <matplotlib.patches.Wedge at 0x7adcafe14250>,
#   <matplotlib.patches.Wedge at 0x7adcb24568c0>,
#   <matplotlib.patches.Wedge at 0x7adcafdb71f0>,
#   <matplotlib.patches.Wedge at 0x7adcadf15360>,
#   <matplotlib.patches.Wedge at 0x7adcadf16da0>,
#   <matplotlib.patches.Wedge at 0x7adcadeb0730>,
#   <matplotlib.patches.Wedge at 0x7adcadeb1540>,
#   <matplotlib.patches.Wedge at 0x7adcadeb2b90>,
#   <matplotlib.patches.Wedge at 0x7adcadeb10c0>,
#   <matplotlib.patches.Wedge at 0x7adcadddf490>,
#   <matplotlib.patches.Wedge at 0x7adcadddf910>,
#   <matplotlib.patches.Wedge at 0x7adcadddfd90>,
#   <matplotlib.patches.Wedge at 0x7adcade28250>,
#   <matplotlib.patches.Wedge at 0x7adcade286d0>,
#   <matplotlib.patches.Wedge at 0x7adcade28b50>,
#   <matplotlib.patches.Wedge at 0x7adcade28fd0>,
#   <matplotlib.patches.Wedge at 0x7adcade29450>,
#   <matplotlib.patches.Wedge at 0x7adcade298d0>,
#   <matplotlib.patches.Wedge at 0x7adcade29d50>,
#   <matplotlib.patches.Wedge at 0x7adcade2a1d0>,
#   <matplotlib.patches.Wedge at 0x7adcade2a650>,
#   <matplotlib.patches.Wedge at 0x7adcade2aad0>,
#   <matplotlib.patches.Wedge at 0x7adcade2af50>,
#   <matplotlib.patches.Wedge at 0x7adcade2b3d0>,
#   <matplotlib.patches.Wedge at 0x7adcade2b850>,
#   <matplotlib.patches.Wedge at 0x7adcade2bcd0>,
#   <matplotlib.patches.Wedge at 0x7adcade5c190>,
#   <matplotlib.patches.Wedge at 0x7adcade5c610>,
#   <matplotlib.patches.Wedge at 0x7adcade5ca90>,
#   <matplotlib.patches.Wedge at 0x7adcade5cf10>,
#   <matplotlib.patches.Wedge at 0x7adcade5d390>,
#   <matplotlib.patches.Wedge at 0x7adcade5d810>,
#   <matplotlib.patches.Wedge at 0x7adcade5dc90>,
#   <matplotlib.patches.Wedge at 0x7adcade5e110>,
#   <matplotlib.patches.Wedge at 0x7adcade5e590>,
#   <matplotlib.patches.Wedge at 0x7adcade5ea10>,
#   <matplotlib.patches.Wedge at 0x7adcade5ee90>,
#   <matplotlib.patches.Wedge at 0x7adcade5f310>,
#   <matplotlib.patches.Wedge at 0x7adcade5f790>,
#   <matplotlib.patches.Wedge at 0x7adcade5fc10>,
#   <matplotlib.patches.Wedge at 0x7adcadc980d0>,
#   <matplotlib.patches.Wedge at 0x7adcadc98550>,
#   <matplotlib.patches.Wedge at 0x7adcadc989d0>,
#   <matplotlib.patches.Wedge at 0x7adcadc98e50>,
#   <matplotlib.patches.Wedge at 0x7adcadc992d0>,
#   <matplotlib.patches.Wedge at 0x7adcadc99750>,
#   <matplotlib.patches.Wedge at 0x7adcadc99bd0>,
#   <matplotlib.patches.Wedge at 0x7adcadc9a050>,
#   <matplotlib.patches.Wedge at 0x7adcadc9a4d0>,
#   <matplotlib.patches.Wedge at 0x7adcadc9a950>,
#   <matplotlib.patches.Wedge at 0x7adcadc9add0>,
#   <matplotlib.patches.Wedge at 0x7adcadc9b250>,
#   <matplotlib.patches.Wedge at 0x7adcadc9b6d0>,
#   <matplotlib.patches.Wedge at 0x7adcadc9bb50>,
#   <matplotlib.patches.Wedge at 0x7adcadc9bfd0>,
#   <matplotlib.patches.Wedge at 0x7adcadcd4490>,
#   <matplotlib.patches.Wedge at 0x7adcadcd4910>,
#   <matplotlib.patches.Wedge at 0x7adcadcd4d90>,
#   <matplotlib.patches.Wedge at 0x7adcadcd5210>,
#   <matplotlib.patches.Wedge at 0x7adcadcd5690>,
#   <matplotlib.patches.Wedge at 0x7adcadcd5b10>,
#   <matplotlib.patches.Wedge at 0x7adcadcd5f90>,
#   <matplotlib.patches.Wedge at 0x7adcadcd6410>,
#   <matplotlib.patches.Wedge at 0x7adcadcd6890>,
#   <matplotlib.patches.Wedge at 0x7adcadcd6d10>,
#   <matplotlib.patches.Wedge at 0x7adcadcd7190>,
#   <matplotlib.patches.Wedge at 0x7adcadcd7610>,
#   <matplotlib.patches.Wedge at 0x7adcadcd7a90>,
#   <matplotlib.patches.Wedge at 0x7adcadcd7f10>,
#   <matplotlib.patches.Wedge at 0x7adcadd103d0>,
#   <matplotlib.patches.Wedge at 0x7adcadd10850>,
#   <matplotlib.patches.Wedge at 0x7adcadd10cd0>,
#   <matplotlib.patches.Wedge at 0x7adcadd11240>,
#   <matplotlib.patches.Wedge at 0x7adcadd11600>,
#   <matplotlib.patches.Wedge at 0x7adcadd11a80>,
#   <matplotlib.patches.Wedge at 0x7adcadd11f00>,
#   <matplotlib.patches.Wedge at 0x7adcadd12380>,
#   <matplotlib.patches.Wedge at 0x7adcadd12800>,
#   <matplotlib.patches.Wedge at 0x7adcadd12c80>,
#   <matplotlib.patches.Wedge at 0x7adcadd13100>,
#   <matplotlib.patches.Wedge at 0x7adcadd13580>,
#   <matplotlib.patches.Wedge at 0x7adcadd13a00>,
#   <matplotlib.patches.Wedge at 0x7adcadd13e80>,
#   <matplotlib.patches.Wedge at 0x7adcadd50340>,
#   <matplotlib.patches.Wedge at 0x7adcadd507c0>,
#   <matplotlib.patches.Wedge at 0x7adcadd50c40>,
#   <matplotlib.patches.Wedge at 0x7adcadd513c0>,
#   <matplotlib.patches.Wedge at 0x7adcadd510c0>,
#   <matplotlib.patches.Wedge at 0x7adcadd51a50>,
#   <matplotlib.patches.Wedge at 0x7adcadd51ed0>,
#   <matplotlib.patches.Wedge at 0x7adcadd52350>,
#   <matplotlib.patches.Wedge at 0x7adcadd527d0>,
#   <matplotlib.patches.Wedge at 0x7adcadd52c50>,
#   <matplotlib.patches.Wedge at 0x7adcadd530d0>,
#   <matplotlib.patches.Wedge at 0x7adcadd53550>,
#   <matplotlib.patches.Wedge at 0x7adcadd539d0>,
#   <matplotlib.patches.Wedge at 0x7adcadd53e50>,
#   <matplotlib.patches.Wedge at 0x7adcadb94310>,
#   <matplotlib.patches.Wedge at 0x7adcadb94790>,
#   <matplotlib.patches.Wedge at 0x7adcadb94c10>,
#   <matplotlib.patches.Wedge at 0x7adcadb95090>,
#   <matplotlib.patches.Wedge at 0x7adcadb95600>,
#   <matplotlib.patches.Wedge at 0x7adcadb959c0>,
#   <matplotlib.patches.Wedge at 0x7adcadb95e40>,
#   <matplotlib.patches.Wedge at 0x7adcadb962c0>,
#   <matplotlib.patches.Wedge at 0x7adcadb96740>,
#   <matplotlib.patches.Wedge at 0x7adcadb96bc0>,
#   <matplotlib.patches.Wedge at 0x7adcadb97040>,
#   <matplotlib.patches.Wedge at 0x7adcadb974c0>,
#   <matplotlib.patches.Wedge at 0x7adcadb97940>,
#   <matplotlib.patches.Wedge at 0x7adcadb97dc0>,
#   <matplotlib.patches.Wedge at 0x7adcadbcc280>,
#   <matplotlib.patches.Wedge at 0x7adcadbcc700>,
#   <matplotlib.patches.Wedge at 0x7adcadbccb80>,
#   <matplotlib.patches.Wedge at 0x7adcadbcd000>,
#   <matplotlib.patches.Wedge at 0x7adcadbcd480>,
#   <matplotlib.patches.Wedge at 0x7adcadbcd900>,
#   <matplotlib.patches.Wedge at 0x7adcadbcdd80>,
#   <matplotlib.patches.Wedge at 0x7adcadbce200>,
#   <matplotlib.patches.Wedge at 0x7adcadbce680>,
#   <matplotlib.patches.Wedge at 0x7adcadbceb00>,
#   <matplotlib.patches.Wedge at 0x7adcadbcef80>,
#   <matplotlib.patches.Wedge at 0x7adcadbcf400>,
#   <matplotlib.patches.Wedge at 0x7adcadbcf880>,
#   <matplotlib.patches.Wedge at 0x7adcadbcfd00>,
#   <matplotlib.patches.Wedge at 0x7adcadc081c0>,
#   <matplotlib.patches.Wedge at 0x7adcadc08640>,
#   <matplotlib.patches.Wedge at 0x7adcadc08ac0>,
#   <matplotlib.patches.Wedge at 0x7adcadc08f40>,
#   <matplotlib.patches.Wedge at 0x7adcadc093c0>,
#   <matplotlib.patches.Wedge at 0x7adcadc09840>,
#   <matplotlib.patches.Wedge at 0x7adcadc09cc0>,
#   <matplotlib.patches.Wedge at 0x7adcadc0a140>,
#   <matplotlib.patches.Wedge at 0x7adcadc0a5c0>,
#   <matplotlib.patches.Wedge at 0x7adcadc0aa40>,
#   <matplotlib.patches.Wedge at 0x7adcadc0aec0>,
#   <matplotlib.patches.Wedge at 0x7adcadc0b340>,
#   <matplotlib.patches.Wedge at 0x7adcadc0b7c0>,
#   <matplotlib.patches.Wedge at 0x7adcadc0bc40>,
#   <matplotlib.patches.Wedge at 0x7adcadc44100>,
#   <matplotlib.patches.Wedge at 0x7adcadc44580>,
#   <matplotlib.patches.Wedge at 0x7adcadc44a00>,
#   <matplotlib.patches.Wedge at 0x7adcadc44e80>,
#   <matplotlib.patches.Wedge at 0x7adcadc45300>,
#   <matplotlib.patches.Wedge at 0x7adcadc45780>,
#   <matplotlib.patches.Wedge at 0x7adcadc45c00>,
#   <matplotlib.patches.Wedge at 0x7adcadc46080>,
#   <matplotlib.patches.Wedge at 0x7adcadc46500>,
#   <matplotlib.patches.Wedge at 0x7adcadc46980>,
#   <matplotlib.patches.Wedge at 0x7adcadc46e00>,
#   <matplotlib.patches.Wedge at 0x7adcadc47280>,
#   <matplotlib.patches.Wedge at 0x7adcadc47700>,
#   <matplotlib.patches.Wedge at 0x7adcadc47b80>,
#   <matplotlib.patches.Wedge at 0x7adcada80040>,
#   <matplotlib.patches.Wedge at 0x7adcada804c0>,
#   <matplotlib.patches.Wedge at 0x7adcada80940>,
#   <matplotlib.patches.Wedge at 0x7adcada80dc0>,
#   <matplotlib.patches.Wedge at 0x7adcada81240>,
#   <matplotlib.patches.Wedge at 0x7adcada816c0>,
#   <matplotlib.patches.Wedge at 0x7adcada81b40>,
#   <matplotlib.patches.Wedge at 0x7adcada81fc0>,
#   <matplotlib.patches.Wedge at 0x7adcada82440>,
#   <matplotlib.patches.Wedge at 0x7adcada828c0>,
#   <matplotlib.patches.Wedge at 0x7adcada82d40>,
#   <matplotlib.patches.Wedge at 0x7adcada831c0>,
#   <matplotlib.patches.Wedge at 0x7adcada83640>,
#   <matplotlib.patches.Wedge at 0x7adcada83ac0>,
#   <matplotlib.patches.Wedge at 0x7adcada83f40>,
#   <matplotlib.patches.Wedge at 0x7adcadab8400>,
#   <matplotlib.patches.Wedge at 0x7adcadab8880>,
#   <matplotlib.patches.Wedge at 0x7adcadab8d00>,
#   <matplotlib.patches.Wedge at 0x7adcadab9180>,
#   <matplotlib.patches.Wedge at 0x7adcadab9600>,
#   <matplotlib.patches.Wedge at 0x7adcadab9a80>,
#   <matplotlib.patches.Wedge at 0x7adcadab9f00>,
#   <matplotlib.patches.Wedge at 0x7adcadaba380>,
#   <matplotlib.patches.Wedge at 0x7adcadaba800>,
#   <matplotlib.patches.Wedge at 0x7adcadabac80>,
#   <matplotlib.patches.Wedge at 0x7adcadabb100>,
#   <matplotlib.patches.Wedge at 0x7adcadabb580>,
#   <matplotlib.patches.Wedge at 0x7adcadabba00>,
#   <matplotlib.patches.Wedge at 0x7adcadabbe80>,
#   <matplotlib.patches.Wedge at 0x7adcadaf4340>,
#   <matplotlib.patches.Wedge at 0x7adcadaf47c0>,
#   <matplotlib.patches.Wedge at 0x7adcadaf4c40>,
#   <matplotlib.patches.Wedge at 0x7adcadaf50c0>,
#   <matplotlib.patches.Wedge at 0x7adcadaf5540>,
#   <matplotlib.patches.Wedge at 0x7adcadaf59c0>,
#   <matplotlib.patches.Wedge at 0x7adcadaf5e40>,
#   <matplotlib.patches.Wedge at 0x7adcadaf62c0>,
#   <matplotlib.patches.Wedge at 0x7adcadaf6740>,
#   <matplotlib.patches.Wedge at 0x7adcadaf6bc0>,
#   <matplotlib.patches.Wedge at 0x7adcadaf7040>,
#   <matplotlib.patches.Wedge at 0x7adcadaf74c0>,
#   <matplotlib.patches.Wedge at 0x7adcadaf7940>,
#   <matplotlib.patches.Wedge at 0x7adcadaf7dc0>,
#   <matplotlib.patches.Wedge at 0x7adcadb34280>,
#   <matplotlib.patches.Wedge at 0x7adcadb34700>,
#   <matplotlib.patches.Wedge at 0x7adcadb34b80>,
#   <matplotlib.patches.Wedge at 0x7adcadb35000>,
#   <matplotlib.patches.Wedge at 0x7adcadb35480>,
#   <matplotlib.patches.Wedge at 0x7adcadb35930>,
#   <matplotlib.patches.Wedge at 0x7adcadb35de0>,
#   <matplotlib.patches.Wedge at 0x7adcadb36260>,
#   <matplotlib.patches.Wedge at 0x7adcadb366e0>,
#   <matplotlib.patches.Wedge at 0x7adcadb36b60>,
#   <matplotlib.patches.Wedge at 0x7adcadb36fe0>,
#   <matplotlib.patches.Wedge at 0x7adcadb37460>,
#   <matplotlib.patches.Wedge at 0x7adcadb378e0>,
#   <matplotlib.patches.Wedge at 0x7adcadb37d60>,
#   <matplotlib.patches.Wedge at 0x7adcadb6c220>,
#   <matplotlib.patches.Wedge at 0x7adcadb6c6a0>,
#   <matplotlib.patches.Wedge at 0x7adcadb6cb20>,
#   <matplotlib.patches.Wedge at 0x7adcadb6cfa0>,
#   <matplotlib.patches.Wedge at 0x7adcadb6d420>,
#   <matplotlib.patches.Wedge at 0x7adcadb6d8a0>,
#   <matplotlib.patches.Wedge at 0x7adcadb6dd20>,
#   <matplotlib.patches.Wedge at 0x7adcadb6e1a0>,
#   <matplotlib.patches.Wedge at 0x7adcadb6e620>,
#   <matplotlib.patches.Wedge at 0x7adcadb6eaa0>,
#   <matplotlib.patches.Wedge at 0x7adcadb6ef20>,
#   <matplotlib.patches.Wedge at 0x7adcadb6f3a0>,
#   <matplotlib.patches.Wedge at 0x7adcadb6f820>,
#   <matplotlib.patches.Wedge at 0x7adcadb6fca0>,
#   <matplotlib.patches.Wedge at 0x7adcad9a8160>,
#   <matplotlib.patches.Wedge at 0x7adcad9a85e0>,
#   <matplotlib.patches.Wedge at 0x7adcad9a8a60>,
#   <matplotlib.patches.Wedge at 0x7adcad9a8ee0>,
#   <matplotlib.patches.Wedge at 0x7adcad9a9360>,
#   <matplotlib.patches.Wedge at 0x7adcad9a97e0>,
#   <matplotlib.patches.Wedge at 0x7adcad9a9c60>,
#   <matplotlib.patches.Wedge at 0x7adcad9aa0e0>,
#   <matplotlib.patches.Wedge at 0x7adcad9aa560>,
#   <matplotlib.patches.Wedge at 0x7adcad9aa9e0>,
#   <matplotlib.patches.Wedge at 0x7adcad9aae60>,
#   <matplotlib.patches.Wedge at 0x7adcad9ab2e0>,
#   <matplotlib.patches.Wedge at 0x7adcad9ab760>,
#   <matplotlib.patches.Wedge at 0x7adcad9abbe0>,
#   <matplotlib.patches.Wedge at 0x7adcad9e40a0>,
#   <matplotlib.patches.Wedge at 0x7adcad9e4520>,
#   <matplotlib.patches.Wedge at 0x7adcad9e49a0>,
#   <matplotlib.patches.Wedge at 0x7adcad9e4e20>,
#   <matplotlib.patches.Wedge at 0x7adcad9e52a0>,
#   <matplotlib.patches.Wedge at 0x7adcad9e5720>,
#   <matplotlib.patches.Wedge at 0x7adcad9e5ba0>,
#   <matplotlib.patches.Wedge at 0x7adcad9e6020>,
#   <matplotlib.patches.Wedge at 0x7adcad9e64a0>,
#   <matplotlib.patches.Wedge at 0x7adcad9e6920>,
#   <matplotlib.patches.Wedge at 0x7adcad9e6da0>,
#   <matplotlib.patches.Wedge at 0x7adcad9e7220>,
#   <matplotlib.patches.Wedge at 0x7adcad9e76a0>,
#   <matplotlib.patches.Wedge at 0x7adcad9e7b20>,
#   <matplotlib.patches.Wedge at 0x7adcad9e7fa0>,
#   <matplotlib.patches.Wedge at 0x7adcada20460>,
#   <matplotlib.patches.Wedge at 0x7adcada208e0>,
#   <matplotlib.patches.Wedge at 0x7adcada20d60>,
#   <matplotlib.patches.Wedge at 0x7adcada211e0>,
#   <matplotlib.patches.Wedge at 0x7adcada21660>,
#   <matplotlib.patches.Wedge at 0x7adcada21ae0>,
#   <matplotlib.patches.Wedge at 0x7adcada21f60>,
#   <matplotlib.patches.Wedge at 0x7adcada223e0>,
#   <matplotlib.patches.Wedge at 0x7adcada22860>,
#   <matplotlib.patches.Wedge at 0x7adcada22ce0>,
#   <matplotlib.patches.Wedge at 0x7adcada23160>,
#   <matplotlib.patches.Wedge at 0x7adcada235e0>,
#   <matplotlib.patches.Wedge at 0x7adcada23a60>,
#   <matplotlib.patches.Wedge at 0x7adcada23ee0>,
#   <matplotlib.patches.Wedge at 0x7adcada5c3a0>,
#   <matplotlib.patches.Wedge at 0x7adcada5c820>,
#   <matplotlib.patches.Wedge at 0x7adcada5cca0>,
#   <matplotlib.patches.Wedge at 0x7adcada5d120>,
#   <matplotlib.patches.Wedge at 0x7adcada5d5a0>,
#   <matplotlib.patches.Wedge at 0x7adcada5da20>,
#   <matplotlib.patches.Wedge at 0x7adcada5dea0>,
#   <matplotlib.patches.Wedge at 0x7adcada5e320>,
#   <matplotlib.patches.Wedge at 0x7adcada5e7a0>,
#   <matplotlib.patches.Wedge at 0x7adcada5ec20>,
#   <matplotlib.patches.Wedge at 0x7adcada5f0a0>,
#   <matplotlib.patches.Wedge at 0x7adcada5f520>,
#   <matplotlib.patches.Wedge at 0x7adcada5f9a0>,
#   <matplotlib.patches.Wedge at 0x7adcada5fe20>,
#   <matplotlib.patches.Wedge at 0x7adcad8942e0>,
#   <matplotlib.patches.Wedge at 0x7adcad894760>,
#   <matplotlib.patches.Wedge at 0x7adcad894be0>,
#   <matplotlib.patches.Wedge at 0x7adcad895060>,
#   <matplotlib.patches.Wedge at 0x7adcad8954e0>,
#   <matplotlib.patches.Wedge at 0x7adcad895960>,
#   <matplotlib.patches.Wedge at 0x7adcad895de0>,
#   <matplotlib.patches.Wedge at 0x7adcad896260>,
#   <matplotlib.patches.Wedge at 0x7adcad8966e0>,
#   <matplotlib.patches.Wedge at 0x7adcad896b60>,
#   <matplotlib.patches.Wedge at 0x7adcad896fe0>,
#   <matplotlib.patches.Wedge at 0x7adcad897460>,
#   <matplotlib.patches.Wedge at 0x7adcad8978e0>,
#   <matplotlib.patches.Wedge at 0x7adcad897d60>,
#   <matplotlib.patches.Wedge at 0x7adcad8d0220>,
#   <matplotlib.patches.Wedge at 0x7adcad8d06a0>,
#   <matplotlib.patches.Wedge at 0x7adcad8d0b20>,
#   <matplotlib.patches.Wedge at 0x7adcad8d0fa0>,
#   <matplotlib.patches.Wedge at 0x7adcad8d1420>,
#   <matplotlib.patches.Wedge at 0x7adcad8d18a0>,
#   <matplotlib.patches.Wedge at 0x7adcad8d1d20>,
#   <matplotlib.patches.Wedge at 0x7adcad8d21a0>,
#   <matplotlib.patches.Wedge at 0x7adcad8d2620>,
#   <matplotlib.patches.Wedge at 0x7adcad8d2aa0>,
#   <matplotlib.patches.Wedge at 0x7adcad8d2f20>,
#   <matplotlib.patches.Wedge at 0x7adcad8d33a0>,
#   <matplotlib.patches.Wedge at 0x7adcad8d3820>,
#   <matplotlib.patches.Wedge at 0x7adcad8d3ca0>,
#   <matplotlib.patches.Wedge at 0x7adcad910160>,
#   <matplotlib.patches.Wedge at 0x7adcad9105e0>,
#   <matplotlib.patches.Wedge at 0x7adcad910a60>,
#   <matplotlib.patches.Wedge at 0x7adcad910ee0>,
#   <matplotlib.patches.Wedge at 0x7adcad911360>,
#   <matplotlib.patches.Wedge at 0x7adcad9117e0>,
#   <matplotlib.patches.Wedge at 0x7adcad911c60>,
#   <matplotlib.patches.Wedge at 0x7adcad9120e0>,
#   <matplotlib.patches.Wedge at 0x7adcad912560>,
#   <matplotlib.patches.Wedge at 0x7adcad9129e0>,
#   <matplotlib.patches.Wedge at 0x7adcad912e60>,
#   <matplotlib.patches.Wedge at 0x7adcad9132e0>,
#   <matplotlib.patches.Wedge at 0x7adcad913760>,
#   <matplotlib.patches.Wedge at 0x7adcad913be0>,
#   <matplotlib.patches.Wedge at 0x7adcad94c1f0>,
#   <matplotlib.patches.Wedge at 0x7adcad94c6a0>,
#   <matplotlib.patches.Wedge at 0x7adcad94ca30>,
#   <matplotlib.patches.Wedge at 0x7adcad94cdf0>,
#   <matplotlib.patches.Wedge at 0x7adcad94d270>,
#   <matplotlib.patches.Wedge at 0x7adcad94d6f0>,
#   <matplotlib.patches.Wedge at 0x7adcad94db70>,
#   <matplotlib.patches.Wedge at 0x7adcad94dff0>,
#   <matplotlib.patches.Wedge at 0x7adcad94e470>,
#   <matplotlib.patches.Wedge at 0x7adcad94e8f0>,
#   <matplotlib.patches.Wedge at 0x7adcad94ed70>,
#   <matplotlib.patches.Wedge at 0x7adcad94f1f0>,
#   <matplotlib.patches.Wedge at 0x7adcad94f670>,
#   <matplotlib.patches.Wedge at 0x7adcad94faf0>,
#   <matplotlib.patches.Wedge at 0x7adcad94ff70>,
#   <matplotlib.patches.Wedge at 0x7adcad78c430>,
#   <matplotlib.patches.Wedge at 0x7adcad78c8b0>,
#   <matplotlib.patches.Wedge at 0x7adcad78cd30>,
#   <matplotlib.patches.Wedge at 0x7adcad78d2a0>,
#   <matplotlib.patches.Wedge at 0x7adcad78d660>,
#   <matplotlib.patches.Wedge at 0x7adcad78dae0>,
#   <matplotlib.patches.Wedge at 0x7adcad78df60>,
#   <matplotlib.patches.Wedge at 0x7adcad78e3e0>,
#   <matplotlib.patches.Wedge at 0x7adcad78e860>,
#   <matplotlib.patches.Wedge at 0x7adcad78ece0>,
#   <matplotlib.patches.Wedge at 0x7adcad78f160>,
#   <matplotlib.patches.Wedge at 0x7adcad78f5e0>,
#   <matplotlib.patches.Wedge at 0x7adcad78fa60>,
#   <matplotlib.patches.Wedge at 0x7adcad78fee0>,
#   <matplotlib.patches.Wedge at 0x7adcad7c43a0>,
#   <matplotlib.patches.Wedge at 0x7adcad7c4820>,
#   <matplotlib.patches.Wedge at 0x7adcad7c4ca0>,
#   <matplotlib.patches.Wedge at 0x7adcad7c5120>,
#   <matplotlib.patches.Wedge at 0x7adcad7c55a0>,
#   <matplotlib.patches.Wedge at 0x7adcad7c5a20>,
#   <matplotlib.patches.Wedge at 0x7adcad7c5ea0>,
#   <matplotlib.patches.Wedge at 0x7adcad7c6320>,
#   <matplotlib.patches.Wedge at 0x7adcad7c67a0>,
#   <matplotlib.patches.Wedge at 0x7adcad7c6c20>,
#   <matplotlib.patches.Wedge at 0x7adcad7c70a0>,
#   <matplotlib.patches.Wedge at 0x7adcad7c7520>,
#   <matplotlib.patches.Wedge at 0x7adcad7c79a0>,
#   <matplotlib.patches.Wedge at 0x7adcad7c7e20>,
#   <matplotlib.patches.Wedge at 0x7adcad8002e0>,
#   <matplotlib.patches.Wedge at 0x7adcad800760>,
#   <matplotlib.patches.Wedge at 0x7adcad800be0>,
#   <matplotlib.patches.Wedge at 0x7adcad801060>,
#   <matplotlib.patches.Wedge at 0x7adcad8014e0>,
#   <matplotlib.patches.Wedge at 0x7adcad801960>,
#   <matplotlib.patches.Wedge at 0x7adcad801de0>,
#   <matplotlib.patches.Wedge at 0x7adcad802260>,
#   <matplotlib.patches.Wedge at 0x7adcad8026e0>,
#   <matplotlib.patches.Wedge at 0x7adcad802b60>,
#   <matplotlib.patches.Wedge at 0x7adcad802fe0>,
#   <matplotlib.patches.Wedge at 0x7adcad803460>,
#   <matplotlib.patches.Wedge at 0x7adcad8038e0>,
#   <matplotlib.patches.Wedge at 0x7adcad803d60>,
#   <matplotlib.patches.Wedge at 0x7adcad83c220>,
#   <matplotlib.patches.Wedge at 0x7adcad83c6a0>,
#   <matplotlib.patches.Wedge at 0x7adcad83cb20>,
#   <matplotlib.patches.Wedge at 0x7adcad83cfa0>,
#   <matplotlib.patches.Wedge at 0x7adcad83d420>,
#   <matplotlib.patches.Wedge at 0x7adcad83d8a0>,
#   <matplotlib.patches.Wedge at 0x7adcad83dd20>,
#   <matplotlib.patches.Wedge at 0x7adcad83e1a0>,
#   <matplotlib.patches.Wedge at 0x7adcad83e620>,
#   <matplotlib.patches.Wedge at 0x7adcad83eaa0>,
#   <matplotlib.patches.Wedge at 0x7adcad83ef20>,
#   <matplotlib.patches.Wedge at 0x7adcad83f3a0>,
#   <matplotlib.patches.Wedge at 0x7adcad83f820>,
#   <matplotlib.patches.Wedge at 0x7adcad83fca0>,
#   <matplotlib.patches.Wedge at 0x7adcad674160>,
#   <matplotlib.patches.Wedge at 0x7adcad6745e0>,
#   <matplotlib.patches.Wedge at 0x7adcad674a60>,
#   <matplotlib.patches.Wedge at 0x7adcad674ee0>,
#   <matplotlib.patches.Wedge at 0x7adcad675360>,
#   <matplotlib.patches.Wedge at 0x7adcad6757e0>,
#   <matplotlib.patches.Wedge at 0x7adcad675c60>,
#   <matplotlib.patches.Wedge at 0x7adcad6760e0>,
#   <matplotlib.patches.Wedge at 0x7adcad676560>,
#   <matplotlib.patches.Wedge at 0x7adcad6769e0>,
#   <matplotlib.patches.Wedge at 0x7adcad676e60>,
#   <matplotlib.patches.Wedge at 0x7adcad6772e0>,
#   <matplotlib.patches.Wedge at 0x7adcad677760>,
#   <matplotlib.patches.Wedge at 0x7adcad677be0>,
#   <matplotlib.patches.Wedge at 0x7adcad6b00a0>,
#   <matplotlib.patches.Wedge at 0x7adcad6b0520>,
#   <matplotlib.patches.Wedge at 0x7adcad6b09a0>,
#   <matplotlib.patches.Wedge at 0x7adcad6b0e20>,
#   <matplotlib.patches.Wedge at 0x7adcad6b12a0>,
#   <matplotlib.patches.Wedge at 0x7adcad6b1720>,
#   <matplotlib.patches.Wedge at 0x7adcad6b1ba0>,
#   <matplotlib.patches.Wedge at 0x7adcad6b2020>,
#   <matplotlib.patches.Wedge at 0x7adcad6b24a0>,
#   <matplotlib.patches.Wedge at 0x7adcad6b2920>,
#   <matplotlib.patches.Wedge at 0x7adcad6b2da0>,
#   <matplotlib.patches.Wedge at 0x7adcad6b3220>,
#   <matplotlib.patches.Wedge at 0x7adcad6b36a0>,
#   <matplotlib.patches.Wedge at 0x7adcad6b3b20>,
#   <matplotlib.patches.Wedge at 0x7adcad6b3fa0>,
#   <matplotlib.patches.Wedge at 0x7adcad6ec460>,
#   <matplotlib.patches.Wedge at 0x7adcad6ec8e0>,
#   <matplotlib.patches.Wedge at 0x7adcad6ecd60>,
#   <matplotlib.patches.Wedge at 0x7adcad6ed1e0>,
#   <matplotlib.patches.Wedge at 0x7adcad6ed660>,
#   <matplotlib.patches.Wedge at 0x7adcad6edae0>,
#   <matplotlib.patches.Wedge at 0x7adcad6edf60>,
#   <matplotlib.patches.Wedge at 0x7adcad6ee3e0>,
#   <matplotlib.patches.Wedge at 0x7adcad6ee860>,
#   <matplotlib.patches.Wedge at 0x7adcad6eece0>,
#   <matplotlib.patches.Wedge at 0x7adcad6ef160>,
#   <matplotlib.patches.Wedge at 0x7adcad6ef5e0>,
#   <matplotlib.patches.Wedge at 0x7adcad6efa60>,
#   <matplotlib.patches.Wedge at 0x7adcad6efee0>,
#   <matplotlib.patches.Wedge at 0x7adcad7283a0>,
#   <matplotlib.patches.Wedge at 0x7adcad728820>,
#   <matplotlib.patches.Wedge at 0x7adcad728ca0>,
#   <matplotlib.patches.Wedge at 0x7adcad729120>,
#   <matplotlib.patches.Wedge at 0x7adcad7295a0>,
#   <matplotlib.patches.Wedge at 0x7adcad729a20>,
#   <matplotlib.patches.Wedge at 0x7adcad729ea0>,
#   <matplotlib.patches.Wedge at 0x7adcad72a320>,
#   <matplotlib.patches.Wedge at 0x7adcad72a7a0>,
#   <matplotlib.patches.Wedge at 0x7adcad72ac20>,
#   <matplotlib.patches.Wedge at 0x7adcad72b0a0>,
#   <matplotlib.patches.Wedge at 0x7adcad72b520>,
#   <matplotlib.patches.Wedge at 0x7adcad72b9a0>,
#   <matplotlib.patches.Wedge at 0x7adcad72be20>,
#   <matplotlib.patches.Wedge at 0x7adcad7642e0>,
#   <matplotlib.patches.Wedge at 0x7adcad764760>,
#   <matplotlib.patches.Wedge at 0x7adcad764be0>,
#   <matplotlib.patches.Wedge at 0x7adcad765060>,
#   <matplotlib.patches.Wedge at 0x7adcad7654e0>,
#   <matplotlib.patches.Wedge at 0x7adcad765960>,
#   <matplotlib.patches.Wedge at 0x7adcad765de0>,
#   <matplotlib.patches.Wedge at 0x7adcad766260>,
#   <matplotlib.patches.Wedge at 0x7adcad7666e0>,
#   <matplotlib.patches.Wedge at 0x7adcad766b60>,
#   <matplotlib.patches.Wedge at 0x7adcad766fe0>,
#   <matplotlib.patches.Wedge at 0x7adcad767460>,
#   <matplotlib.patches.Wedge at 0x7adcad7678e0>,
#   <matplotlib.patches.Wedge at 0x7adcad767d60>,
#   <matplotlib.patches.Wedge at 0x7adcad5a0220>,
#   <matplotlib.patches.Wedge at 0x7adcad5a06a0>,
#   <matplotlib.patches.Wedge at 0x7adcad5a0b20>,
#   <matplotlib.patches.Wedge at 0x7adcad5a0fa0>,
#   <matplotlib.patches.Wedge at 0x7adcad5a1420>,
#   <matplotlib.patches.Wedge at 0x7adcad5a18a0>,
#   <matplotlib.patches.Wedge at 0x7adcad5a1d20>,
#   <matplotlib.patches.Wedge at 0x7adcad913fa0>,
#   <matplotlib.patches.Wedge at 0x7adcad5a25f0>,
#   <matplotlib.patches.Wedge at 0x7adcad5a2a70>,
#   <matplotlib.patches.Wedge at 0x7adcad5a2ef0>,
#   <matplotlib.patches.Wedge at 0x7adcad5a3370>,
#   <matplotlib.patches.Wedge at 0x7adcad5a37f0>,
#   <matplotlib.patches.Wedge at 0x7adcad5a3c70>,
#   <matplotlib.patches.Wedge at 0x7adcad5e4130>,
#   <matplotlib.patches.Wedge at 0x7adcad5e45b0>,
#   <matplotlib.patches.Wedge at 0x7adcad5e4a30>,
#   <matplotlib.patches.Wedge at 0x7adcad5e4f70>,
#   <matplotlib.patches.Wedge at 0x7adcad5e5360>,
#   <matplotlib.patches.Wedge at 0x7adcad5e57e0>,
#   <matplotlib.patches.Wedge at 0x7adcad5e5c60>,
#   <matplotlib.patches.Wedge at 0x7adcad5e60e0>,
#   <matplotlib.patches.Wedge at 0x7adcad5e6560>,
#   <matplotlib.patches.Wedge at 0x7adcad5e69e0>,
#   <matplotlib.patches.Wedge at 0x7adcad5e6e60>,
#   <matplotlib.patches.Wedge at 0x7adcad5e72e0>,
#   <matplotlib.patches.Wedge at 0x7adcad5e7760>,
#   <matplotlib.patches.Wedge at 0x7adcad5e7be0>,
#   <matplotlib.patches.Wedge at 0x7adcad6180a0>,
#   <matplotlib.patches.Wedge at 0x7adcad618520>,
#   <matplotlib.patches.Wedge at 0x7adcad6189a0>,
#   <matplotlib.patches.Wedge at 0x7adcad618e20>,
#   <matplotlib.patches.Wedge at 0x7adcad6192a0>,
#   <matplotlib.patches.Wedge at 0x7adcad619720>,
#   <matplotlib.patches.Wedge at 0x7adcad619ba0>,
#   <matplotlib.patches.Wedge at 0x7adcad61a020>,
#   <matplotlib.patches.Wedge at 0x7adcad61a4a0>,
#   <matplotlib.patches.Wedge at 0x7adcad61a920>,
#   <matplotlib.patches.Wedge at 0x7adcad61ada0>,
#   <matplotlib.patches.Wedge at 0x7adcad61b220>,
#   <matplotlib.patches.Wedge at 0x7adcad61b6a0>,
#   <matplotlib.patches.Wedge at 0x7adcad61bb20>,
#   <matplotlib.patches.Wedge at 0x7adcad61bfa0>,
#   <matplotlib.patches.Wedge at 0x7adcad64c460>,
#   <matplotlib.patches.Wedge at 0x7adcad64c8e0>,
#   <matplotlib.patches.Wedge at 0x7adcad64cd60>,
#   <matplotlib.patches.Wedge at 0x7adcad64d1e0>,
#   <matplotlib.patches.Wedge at 0x7adcad64d660>,
#   <matplotlib.patches.Wedge at 0x7adcad64dae0>,
#   <matplotlib.patches.Wedge at 0x7adcad64df60>,
#   <matplotlib.patches.Wedge at 0x7adcad64e3e0>,
#   <matplotlib.patches.Wedge at 0x7adcad64e860>,
#   <matplotlib.patches.Wedge at 0x7adcad64ece0>,
#   <matplotlib.patches.Wedge at 0x7adcad64f160>,
#   <matplotlib.patches.Wedge at 0x7adcad64f5e0>,
#   <matplotlib.patches.Wedge at 0x7adcad64fa60>,
#   <matplotlib.patches.Wedge at 0x7adcad64fee0>,
#   <matplotlib.patches.Wedge at 0x7adcad48c3a0>,
#   <matplotlib.patches.Wedge at 0x7adcad48c820>,
#   <matplotlib.patches.Wedge at 0x7adcad48cca0>,
#   <matplotlib.patches.Wedge at 0x7adcad48d120>,
#   <matplotlib.patches.Wedge at 0x7adcad48d5a0>,
#   <matplotlib.patches.Wedge at 0x7adcad48da20>,
#   <matplotlib.patches.Wedge at 0x7adcad48dea0>,
#   <matplotlib.patches.Wedge at 0x7adcad48e320>,
#   <matplotlib.patches.Wedge at 0x7adcad48e7a0>,
#   <matplotlib.patches.Wedge at 0x7adcad48ec20>,
#   <matplotlib.patches.Wedge at 0x7adcad48f0a0>,
#   <matplotlib.patches.Wedge at 0x7adcad48f520>,
#   <matplotlib.patches.Wedge at 0x7adcad48f9a0>,
#   <matplotlib.patches.Wedge at 0x7adcad48fe20>,
#   <matplotlib.patches.Wedge at 0x7adcad4c82e0>,
#   <matplotlib.patches.Wedge at 0x7adcad4c8760>,
#   <matplotlib.patches.Wedge at 0x7adcad4c8be0>,
#   <matplotlib.patches.Wedge at 0x7adcad4c9060>,
#   <matplotlib.patches.Wedge at 0x7adcad4c94e0>,
#   <matplotlib.patches.Wedge at 0x7adcad4c9960>,
#   <matplotlib.patches.Wedge at 0x7adcad4c9de0>,
#   <matplotlib.patches.Wedge at 0x7adcad4ca260>,
#   <matplotlib.patches.Wedge at 0x7adcad4ca6e0>,
#   <matplotlib.patches.Wedge at 0x7adcad4cab60>,
#   <matplotlib.patches.Wedge at 0x7adcad4cafe0>,
#   <matplotlib.patches.Wedge at 0x7adcad4cb460>,
#   <matplotlib.patches.Wedge at 0x7adcad4cb8e0>,
#   <matplotlib.patches.Wedge at 0x7adcad4cbd60>,
#   <matplotlib.patches.Wedge at 0x7adcad50c220>,
#   <matplotlib.patches.Wedge at 0x7adcad50c6a0>,
#   <matplotlib.patches.Wedge at 0x7adcad50cb20>,
#   <matplotlib.patches.Wedge at 0x7adcad50cfa0>,
#   <matplotlib.patches.Wedge at 0x7adcad50d420>,
#   <matplotlib.patches.Wedge at 0x7adcad50d8a0>,
#   <matplotlib.patches.Wedge at 0x7adcad50dd20>,
#   <matplotlib.patches.Wedge at 0x7adcad50e1a0>,
#   <matplotlib.patches.Wedge at 0x7adcad50e620>,
#   <matplotlib.patches.Wedge at 0x7adcad50eaa0>,
#   <matplotlib.patches.Wedge at 0x7adcad50ef20>,
#   <matplotlib.patches.Wedge at 0x7adcad50f3a0>,
#   <matplotlib.patches.Wedge at 0x7adcad50f820>,
#   <matplotlib.patches.Wedge at 0x7adcad50fca0>,
#   <matplotlib.patches.Wedge at 0x7adcad540160>,
#   <matplotlib.patches.Wedge at 0x7adcad5405e0>,
#   <matplotlib.patches.Wedge at 0x7adcad540a60>,
#   <matplotlib.patches.Wedge at 0x7adcad540ee0>,
#   <matplotlib.patches.Wedge at 0x7adcad541360>,
#   <matplotlib.patches.Wedge at 0x7adcad5417e0>,
#   <matplotlib.patches.Wedge at 0x7adcad541c60>,
#   <matplotlib.patches.Wedge at 0x7adcad5420e0>,
#   <matplotlib.patches.Wedge at 0x7adcad542560>,
#   <matplotlib.patches.Wedge at 0x7adcad5429e0>,
#   <matplotlib.patches.Wedge at 0x7adcad542e60>,
#   <matplotlib.patches.Wedge at 0x7adcad5432e0>,
#   <matplotlib.patches.Wedge at 0x7adcad543760>,
#   <matplotlib.patches.Wedge at 0x7adcad543be0>,
#   <matplotlib.patches.Wedge at 0x7adcad37c0a0>,
#   <matplotlib.patches.Wedge at 0x7adcad37c520>,
#   <matplotlib.patches.Wedge at 0x7adcad37c9a0>,
#   <matplotlib.patches.Wedge at 0x7adcad37ce20>,
#   <matplotlib.patches.Wedge at 0x7adcad37d2a0>,
#   <matplotlib.patches.Wedge at 0x7adcad37d720>,
#   <matplotlib.patches.Wedge at 0x7adcad37dba0>,
#   <matplotlib.patches.Wedge at 0x7adcad37e020>,
#   <matplotlib.patches.Wedge at 0x7adcad37e4a0>,
#   <matplotlib.patches.Wedge at 0x7adcad37e920>,
#   <matplotlib.patches.Wedge at 0x7adcad37eda0>,
#   <matplotlib.patches.Wedge at 0x7adcad37f220>,
#   <matplotlib.patches.Wedge at 0x7adcad37f6a0>,
#   <matplotlib.patches.Wedge at 0x7adcad37fb20>,
#   <matplotlib.patches.Wedge at 0x7adcad37ffa0>,
#   <matplotlib.patches.Wedge at 0x7adcad3b8460>,
#   <matplotlib.patches.Wedge at 0x7adcad3b88e0>,
#   <matplotlib.patches.Wedge at 0x7adcad3b8d60>,
#   <matplotlib.patches.Wedge at 0x7adcad3b91e0>,
#   <matplotlib.patches.Wedge at 0x7adcad3b9660>,
#   <matplotlib.patches.Wedge at 0x7adcad3b9ae0>,
#   <matplotlib.patches.Wedge at 0x7adcad3b9f60>,
#   <matplotlib.patches.Wedge at 0x7adcad3ba3e0>,
#   <matplotlib.patches.Wedge at 0x7adcad3ba860>,
#   <matplotlib.patches.Wedge at 0x7adcad3bace0>,
#   <matplotlib.patches.Wedge at 0x7adcad3bb160>,
#   <matplotlib.patches.Wedge at 0x7adcad3bb5e0>,
#   <matplotlib.patches.Wedge at 0x7adcad3bba60>,
#   <matplotlib.patches.Wedge at 0x7adcad3bbfd0>,
#   <matplotlib.patches.Wedge at 0x7adcad3f43d0>,
#   <matplotlib.patches.Wedge at 0x7adcad3f4850>,
#   <matplotlib.patches.Wedge at 0x7adcad3f4cd0>,
#   <matplotlib.patches.Wedge at 0x7adcad3f5150>,
#   <matplotlib.patches.Wedge at 0x7adcad3f55d0>,
#   <matplotlib.patches.Wedge at 0x7adcad3f5a50>,
#   <matplotlib.patches.Wedge at 0x7adcad3f5ed0>,
#   <matplotlib.patches.Wedge at 0x7adcad3f6350>,
#   <matplotlib.patches.Wedge at 0x7adcad3f67d0>,
#   <matplotlib.patches.Wedge at 0x7adcad3f6c50>,
#   <matplotlib.patches.Wedge at 0x7adcad3f70d0>,
#   <matplotlib.patches.Wedge at 0x7adcad3f7550>,
#   <matplotlib.patches.Wedge at 0x7adcad3f79d0>,
#   <matplotlib.patches.Wedge at 0x7adcad3f7e50>,
#   <matplotlib.patches.Wedge at 0x7adcad42c310>,
#   <matplotlib.patches.Wedge at 0x7adcad42c790>,
#   <matplotlib.patches.Wedge at 0x7adcad42cc10>,
#   <matplotlib.patches.Wedge at 0x7adcad42d090>,
#   <matplotlib.patches.Wedge at 0x7adcad42d510>,
#   <matplotlib.patches.Wedge at 0x7adcad42d990>,
#   <matplotlib.patches.Wedge at 0x7adcad42de10>,
#   <matplotlib.patches.Wedge at 0x7adcad42e290>,
#   <matplotlib.patches.Wedge at 0x7adcad42e710>,
#   <matplotlib.patches.Wedge at 0x7adcad42eb90>,
#   <matplotlib.patches.Wedge at 0x7adcad42f010>,
#   <matplotlib.patches.Wedge at 0x7adcad42f490>,
#   <matplotlib.patches.Wedge at 0x7adcad42f910>,
#   <matplotlib.patches.Wedge at 0x7adcad42fd90>,
#   <matplotlib.patches.Wedge at 0x7adcad464250>,
#   <matplotlib.patches.Wedge at 0x7adcad4646d0>,
#   <matplotlib.patches.Wedge at 0x7adcad464b50>,
#   <matplotlib.patches.Wedge at 0x7adcad464fd0>,
#   <matplotlib.patches.Wedge at 0x7adcad465450>,
#   <matplotlib.patches.Wedge at 0x7adcad4658d0>,
#   <matplotlib.patches.Wedge at 0x7adcad465d50>,
#   <matplotlib.patches.Wedge at 0x7adcad4661d0>,
#   <matplotlib.patches.Wedge at 0x7adcad466650>,
#   <matplotlib.patches.Wedge at 0x7adcad466ad0>,
#   <matplotlib.patches.Wedge at 0x7adcad466f50>,
#   <matplotlib.patches.Wedge at 0x7adcad4673d0>,
#   <matplotlib.patches.Wedge at 0x7adcad467850>,
#   <matplotlib.patches.Wedge at 0x7adcad467cd0>,
#   <matplotlib.patches.Wedge at 0x7adcad2a8190>,
#   <matplotlib.patches.Wedge at 0x7adcad2a8610>,
#   <matplotlib.patches.Wedge at 0x7adcad2a8a90>,
#   <matplotlib.patches.Wedge at 0x7adcad2a8f10>,
#   <matplotlib.patches.Wedge at 0x7adcad2a9390>,
#   <matplotlib.patches.Wedge at 0x7adcad2a9810>,
#   <matplotlib.patches.Wedge at 0x7adcad2a9c90>,
#   <matplotlib.patches.Wedge at 0x7adcad2aa110>,
#   <matplotlib.patches.Wedge at 0x7adcad2aa590>,
#   <matplotlib.patches.Wedge at 0x7adcad2aaa10>,
#   <matplotlib.patches.Wedge at 0x7adcad2aae90>,
#   <matplotlib.patches.Wedge at 0x7adcad2ab310>,
#   <matplotlib.patches.Wedge at 0x7adcad2ab790>,
#   <matplotlib.patches.Wedge at 0x7adcad2abc10>,
#   <matplotlib.patches.Wedge at 0x7adcad2e40d0>,
#   <matplotlib.patches.Wedge at 0x7adcad2e4550>,
#   <matplotlib.patches.Wedge at 0x7adcad2e49d0>,
#   <matplotlib.patches.Wedge at 0x7adcad2e4e50>,
#   <matplotlib.patches.Wedge at 0x7adcad2e52d0>,
#   <matplotlib.patches.Wedge at 0x7adcad2e5750>,
#   <matplotlib.patches.Wedge at 0x7adcad2e5bd0>,
#   <matplotlib.patches.Wedge at 0x7adcad2e6050>,
#   <matplotlib.patches.Wedge at 0x7adcad2e64d0>,
#   <matplotlib.patches.Wedge at 0x7adcad2e6950>,
#   <matplotlib.patches.Wedge at 0x7adcad2e6dd0>,
#   <matplotlib.patches.Wedge at 0x7adcad2e7250>,
#   <matplotlib.patches.Wedge at 0x7adcad2e76d0>,
#   <matplotlib.patches.Wedge at 0x7adcad2e7b50>,
#   <matplotlib.patches.Wedge at 0x7adcad2e7fd0>,
#   <matplotlib.patches.Wedge at 0x7adcad31c490>,
#   <matplotlib.patches.Wedge at 0x7adcad31c910>,
#   <matplotlib.patches.Wedge at 0x7adcad31cd90>,
#   <matplotlib.patches.Wedge at 0x7adcad31d210>,
#   <matplotlib.patches.Wedge at 0x7adcad31d690>,
#   <matplotlib.patches.Wedge at 0x7adcad31db10>,
#   <matplotlib.patches.Wedge at 0x7adcad31df90>,
#   <matplotlib.patches.Wedge at 0x7adcad31e410>,
#   <matplotlib.patches.Wedge at 0x7adcad31e830>,
#   <matplotlib.patches.Wedge at 0x7adcad31ec20>,
#   <matplotlib.patches.Wedge at 0x7adcad31f0a0>,
#   <matplotlib.patches.Wedge at 0x7adcad31f520>,
#   <matplotlib.patches.Wedge at 0x7adcad31f9a0>,
#   <matplotlib.patches.Wedge at 0x7adcad31fe20>,
#   <matplotlib.patches.Wedge at 0x7adcad3542e0>,
#   <matplotlib.patches.Wedge at 0x7adcad354760>,
#   <matplotlib.patches.Wedge at 0x7adcad354be0>,
#   <matplotlib.patches.Wedge at 0x7adcad355060>,
#   <matplotlib.patches.Wedge at 0x7adcad3554e0>,
#   <matplotlib.patches.Wedge at 0x7adcad355960>,
#   <matplotlib.patches.Wedge at 0x7adcad355de0>,
#   <matplotlib.patches.Wedge at 0x7adcad356260>,
#   <matplotlib.patches.Wedge at 0x7adcad3566e0>,
#   <matplotlib.patches.Wedge at 0x7adcad356b60>,
#   <matplotlib.patches.Wedge at 0x7adcad356fe0>,
#   <matplotlib.patches.Wedge at 0x7adcad357460>,
#   <matplotlib.patches.Wedge at 0x7adcad3578e0>,
#   <matplotlib.patches.Wedge at 0x7adcad357d60>,
#   <matplotlib.patches.Wedge at 0x7adcad198220>,
#   <matplotlib.patches.Wedge at 0x7adcad1986a0>,
#   <matplotlib.patches.Wedge at 0x7adcad198be0>,
#   <matplotlib.patches.Wedge at 0x7adcad198fd0>,
#   <matplotlib.patches.Wedge at 0x7adcad199450>,
#   <matplotlib.patches.Wedge at 0x7adcad1998d0>,
#   <matplotlib.patches.Wedge at 0x7adcad199d50>,
#   <matplotlib.patches.Wedge at 0x7adcad19a1d0>,
#   <matplotlib.patches.Wedge at 0x7adcad19a650>,
#   <matplotlib.patches.Wedge at 0x7adcad19aad0>,
#   <matplotlib.patches.Wedge at 0x7adcad19af50>,
#   <matplotlib.patches.Wedge at 0x7adcad19b3d0>,
#   <matplotlib.patches.Wedge at 0x7adcad19b850>,
#   <matplotlib.patches.Wedge at 0x7adcad19bcd0>,
#   <matplotlib.patches.Wedge at 0x7adcad1cc190>,
#   <matplotlib.patches.Wedge at 0x7adcad1cc610>,
#   <matplotlib.patches.Wedge at 0x7adcad1cca90>,
#   <matplotlib.patches.Wedge at 0x7adcad1ccf10>,
#   <matplotlib.patches.Wedge at 0x7adcad1cd390>,
#   <matplotlib.patches.Wedge at 0x7adcad1cd810>,
#   <matplotlib.patches.Wedge at 0x7adcad1cdc90>,
#   <matplotlib.patches.Wedge at 0x7adcad1ce110>,
#   <matplotlib.patches.Wedge at 0x7adcad1ce590>,
#   <matplotlib.patches.Wedge at 0x7adcad1cea10>,
#   <matplotlib.patches.Wedge at 0x7adcad1cee90>,
#   <matplotlib.patches.Wedge at 0x7adcad1cf310>,
#   <matplotlib.patches.Wedge at 0x7adcad1cf790>,
#   <matplotlib.patches.Wedge at 0x7adcad1cfc10>,
#   <matplotlib.patches.Wedge at 0x7adcad20c0d0>,
#   <matplotlib.patches.Wedge at 0x7adcad20c550>,
#   <matplotlib.patches.Wedge at 0x7adcad20c9d0>,
#   <matplotlib.patches.Wedge at 0x7adcad20ce50>,
#   <matplotlib.patches.Wedge at 0x7adcad20d2d0>,
#   <matplotlib.patches.Wedge at 0x7adcad20d750>,
#   <matplotlib.patches.Wedge at 0x7adcad20dbd0>,
#   <matplotlib.patches.Wedge at 0x7adcad20e050>,
#   <matplotlib.patches.Wedge at 0x7adcad20e4d0>,
#   <matplotlib.patches.Wedge at 0x7adcad20e950>,
#   <matplotlib.patches.Wedge at 0x7adcad20edd0>,
#   <matplotlib.patches.Wedge at 0x7adcad20f250>,
#   <matplotlib.patches.Wedge at 0x7adcad20f6d0>,
#   <matplotlib.patches.Wedge at 0x7adcad20fb50>,
#   <matplotlib.patches.Wedge at 0x7adcad20ffd0>,
#   <matplotlib.patches.Wedge at 0x7adcad244490>,
#   <matplotlib.patches.Wedge at 0x7adcad244910>,
#   <matplotlib.patches.Wedge at 0x7adcad244d90>,
#   <matplotlib.patches.Wedge at 0x7adcad245210>,
#   <matplotlib.patches.Wedge at 0x7adcad245690>,
#   <matplotlib.patches.Wedge at 0x7adcad245b10>,
#   <matplotlib.patches.Wedge at 0x7adcad245f90>,
#   <matplotlib.patches.Wedge at 0x7adcad246410>,
#   <matplotlib.patches.Wedge at 0x7adcad246890>,
#   <matplotlib.patches.Wedge at 0x7adcad246d10>,
#   <matplotlib.patches.Wedge at 0x7adcad247190>,
#   <matplotlib.patches.Wedge at 0x7adcad247610>,
#   <matplotlib.patches.Wedge at 0x7adcad247a90>,
#   <matplotlib.patches.Wedge at 0x7adcad247f10>,
#   <matplotlib.patches.Wedge at 0x7adcad0883d0>,
#   <matplotlib.patches.Wedge at 0x7adcad088850>,
#   <matplotlib.patches.Wedge at 0x7adcad088cd0>,
#   <matplotlib.patches.Wedge at 0x7adcad089150>,
#   <matplotlib.patches.Wedge at 0x7adcad0895d0>,
#   <matplotlib.patches.Wedge at 0x7adcad089a50>,
#   <matplotlib.patches.Wedge at 0x7adcad089ed0>,
#   <matplotlib.patches.Wedge at 0x7adcad08a350>,
#   <matplotlib.patches.Wedge at 0x7adcad08a7d0>,
#   <matplotlib.patches.Wedge at 0x7adcad08ac50>,
#   <matplotlib.patches.Wedge at 0x7adcad08b0d0>,
#   <matplotlib.patches.Wedge at 0x7adcad08b550>,
#   <matplotlib.patches.Wedge at 0x7adcad08b9d0>,
#   <matplotlib.patches.Wedge at 0x7adcad08be50>,
#   <matplotlib.patches.Wedge at 0x7adcad0bc310>,
#   <matplotlib.patches.Wedge at 0x7adcad0bc790>,
#   <matplotlib.patches.Wedge at 0x7adcad0bcc10>,
#   <matplotlib.patches.Wedge at 0x7adcad0bd090>,
#   <matplotlib.patches.Wedge at 0x7adcad0bd510>,
#   <matplotlib.patches.Wedge at 0x7adcad0bd990>,
#   <matplotlib.patches.Wedge at 0x7adcad0bde10>,
#   <matplotlib.patches.Wedge at 0x7adcad0be290>,
#   <matplotlib.patches.Wedge at 0x7adcad0be710>,
#   <matplotlib.patches.Wedge at 0x7adcad0beb90>,
#   <matplotlib.patches.Wedge at 0x7adcad0bf010>,
#   <matplotlib.patches.Wedge at 0x7adcad0bf490>,
#   <matplotlib.patches.Wedge at 0x7adcad0bf910>,
#   <matplotlib.patches.Wedge at 0x7adcad0bfd90>,
#   <matplotlib.patches.Wedge at 0x7adcad0f8250>,
#   <matplotlib.patches.Wedge at 0x7adcad0f86d0>,
#   <matplotlib.patches.Wedge at 0x7adcad0f8b50>,
#   <matplotlib.patches.Wedge at 0x7adcad0f8fd0>,
#   <matplotlib.patches.Wedge at 0x7adcad0f9450>,
#   <matplotlib.patches.Wedge at 0x7adcad0f98d0>,
#   <matplotlib.patches.Wedge at 0x7adcad0f9d50>,
#   <matplotlib.patches.Wedge at 0x7adcad0fa1d0>,
#   <matplotlib.patches.Wedge at 0x7adcad0fa650>,
#   <matplotlib.patches.Wedge at 0x7adcad0faad0>,
#   <matplotlib.patches.Wedge at 0x7adcad0faf50>,
#   <matplotlib.patches.Wedge at 0x7adcad0fb3d0>,
#   <matplotlib.patches.Wedge at 0x7adcad0fb850>,
#   <matplotlib.patches.Wedge at 0x7adcad0fbcd0>,
#   <matplotlib.patches.Wedge at 0x7adcad134190>,
#   <matplotlib.patches.Wedge at 0x7adcad134610>,
#   <matplotlib.patches.Wedge at 0x7adcad134a90>,
#   <matplotlib.patches.Wedge at 0x7adcad134f10>,
#   <matplotlib.patches.Wedge at 0x7adcad135390>,
#   <matplotlib.patches.Wedge at 0x7adcad135810>,
#   <matplotlib.patches.Wedge at 0x7adcad135c90>,
#   <matplotlib.patches.Wedge at 0x7adcad136110>,
#   <matplotlib.patches.Wedge at 0x7adcad136590>,
#   <matplotlib.patches.Wedge at 0x7adcad136a10>,
#   <matplotlib.patches.Wedge at 0x7adcad136e90>,
#   <matplotlib.patches.Wedge at 0x7adcad137310>,
#   <matplotlib.patches.Wedge at 0x7adcad137790>,
#   <matplotlib.patches.Wedge at 0x7adcad137c10>,
#   <matplotlib.patches.Wedge at 0x7adcacf780d0>,
#   <matplotlib.patches.Wedge at 0x7adcacf78550>,
#   <matplotlib.patches.Wedge at 0x7adcacf789d0>,
#   <matplotlib.patches.Wedge at 0x7adcacf78e50>,
#   <matplotlib.patches.Wedge at 0x7adcacf792d0>,
#   <matplotlib.patches.Wedge at 0x7adcacf79750>,
#   <matplotlib.patches.Wedge at 0x7adcacf79bd0>,
#   <matplotlib.patches.Wedge at 0x7adcacf7a050>,
#   <matplotlib.patches.Wedge at 0x7adcacf7a4d0>,
#   <matplotlib.patches.Wedge at 0x7adcacf7a950>,
#   <matplotlib.patches.Wedge at 0x7adcacf7add0>,
#   <matplotlib.patches.Wedge at 0x7adcacf7b250>,
#   <matplotlib.patches.Wedge at 0x7adcacf7b6d0>,
#   <matplotlib.patches.Wedge at 0x7adcacf7bb50>,
#   <matplotlib.patches.Wedge at 0x7adcacf7bfd0>,
#   <matplotlib.patches.Wedge at 0x7adcacfb0490>,
#   <matplotlib.patches.Wedge at 0x7adcacfb0910>,
#   <matplotlib.patches.Wedge at 0x7adcacfb0d90>,
#   <matplotlib.patches.Wedge at 0x7adcacfb1210>,
#   <matplotlib.patches.Wedge at 0x7adcacfb1690>,
#   <matplotlib.patches.Wedge at 0x7adcacfb1b10>,
#   <matplotlib.patches.Wedge at 0x7adcacfb1f90>,
#   <matplotlib.patches.Wedge at 0x7adcacfb2500>,
#   <matplotlib.patches.Wedge at 0x7adcacfb28c0>,
#   <matplotlib.patches.Wedge at 0x7adcacfb2d40>,
#   <matplotlib.patches.Wedge at 0x7adcacfb31c0>,
#   <matplotlib.patches.Wedge at 0x7adcacfb3640>,
#   <matplotlib.patches.Wedge at 0x7adcacfb3ac0>,
#   <matplotlib.patches.Wedge at 0x7adcacfb3f40>,
#   <matplotlib.patches.Wedge at 0x7adcacfec400>,
#   <matplotlib.patches.Wedge at 0x7adcacfec880>,
#   <matplotlib.patches.Wedge at 0x7adcacfecd00>,
#   <matplotlib.patches.Wedge at 0x7adcacfed180>,
#   <matplotlib.patches.Wedge at 0x7adcacfed600>,
#   <matplotlib.patches.Wedge at 0x7adcacfeda80>,
#   <matplotlib.patches.Wedge at 0x7adcacfedf00>,
#   <matplotlib.patches.Wedge at 0x7adcacfee380>,
#   <matplotlib.patches.Wedge at 0x7adcacfee800>,
#   <matplotlib.patches.Wedge at 0x7adcacfeec80>,
#   <matplotlib.patches.Wedge at 0x7adcacfef100>,
#   <matplotlib.patches.Wedge at 0x7adcacfef580>,
#   <matplotlib.patches.Wedge at 0x7adcacfefa00>,
#   <matplotlib.patches.Wedge at 0x7adcacfefe80>,
#   <matplotlib.patches.Wedge at 0x7adcad020340>,
#   <matplotlib.patches.Wedge at 0x7adcad0207c0>,
#   <matplotlib.patches.Wedge at 0x7adcad020c40>,
#   <matplotlib.patches.Wedge at 0x7adcad0210c0>,
#   <matplotlib.patches.Wedge at 0x7adcad021540>,
#   <matplotlib.patches.Wedge at 0x7adcad0219c0>,
#   <matplotlib.patches.Wedge at 0x7adcad021e40>,
#   <matplotlib.patches.Wedge at 0x7adcad0222c0>,
#   <matplotlib.patches.Wedge at 0x7adcad022740>,
#   <matplotlib.patches.Wedge at 0x7adcad022bc0>,
#   <matplotlib.patches.Wedge at 0x7adcad023040>,
#   <matplotlib.patches.Wedge at 0x7adcad0234c0>,
#   <matplotlib.patches.Wedge at 0x7adcad023940>,
#   <matplotlib.patches.Wedge at 0x7adcad023dc0>,
#   <matplotlib.patches.Wedge at 0x7adcad0642b0>,
#   <matplotlib.patches.Wedge at 0x7adcad064730>,
#   <matplotlib.patches.Wedge at 0x7adcad064bb0>,
#   <matplotlib.patches.Wedge at 0x7adcad065030>,
#   <matplotlib.patches.Wedge at 0x7adcad0654b0>,
#   <matplotlib.patches.Wedge at 0x7adcad065930>,
#   <matplotlib.patches.Wedge at 0x7adcad065db0>,
#   <matplotlib.patches.Wedge at 0x7adcad066230>,
#   <matplotlib.patches.Wedge at 0x7adcad0666b0>,
#   <matplotlib.patches.Wedge at 0x7adcad066b30>,
#   <matplotlib.patches.Wedge at 0x7adcad066fb0>,
#   <matplotlib.patches.Wedge at 0x7adcad067430>,
#   <matplotlib.patches.Wedge at 0x7adcad0678b0>,
#   <matplotlib.patches.Wedge at 0x7adcad067d30>,
#   <matplotlib.patches.Wedge at 0x7adcace9c1f0>,
#   <matplotlib.patches.Wedge at 0x7adcace9c670>,
#   <matplotlib.patches.Wedge at 0x7adcace9caf0>,
#   <matplotlib.patches.Wedge at 0x7adcace9cf70>,
#   <matplotlib.patches.Wedge at 0x7adcace9d3f0>,
#   <matplotlib.patches.Wedge at 0x7adcace9d870>,
#   <matplotlib.patches.Wedge at 0x7adcace9dcf0>,
#   <matplotlib.patches.Wedge at 0x7adcace9e170>,
#   <matplotlib.patches.Wedge at 0x7adcace9e5f0>,
#   <matplotlib.patches.Wedge at 0x7adcace9ea10>,
#   <matplotlib.patches.Wedge at 0x7adcace9eec0>,
#   <matplotlib.patches.Wedge at 0x7adcace9f340>,
#   <matplotlib.patches.Wedge at 0x7adcace9f7c0>,
#   <matplotlib.patches.Wedge at 0x7adcace9fc40>,
#   <matplotlib.patches.Wedge at 0x7adcacedc100>,
#   <matplotlib.patches.Wedge at 0x7adcacedc580>,
#   <matplotlib.patches.Wedge at 0x7adcacedca00>,
#   <matplotlib.patches.Wedge at 0x7adcacedce80>,
#   <matplotlib.patches.Wedge at 0x7adcacedd300>,
#   <matplotlib.patches.Wedge at 0x7adcacedd780>,
#   <matplotlib.patches.Wedge at 0x7adcaceddc00>,
#   <matplotlib.patches.Wedge at 0x7adcacede080>,
#   <matplotlib.patches.Wedge at 0x7adcacede500>,
#   <matplotlib.patches.Wedge at 0x7adcacede980>,
#   <matplotlib.patches.Wedge at 0x7adcacedee00>,
#   <matplotlib.patches.Wedge at 0x7adcacedf280>,
#   <matplotlib.patches.Wedge at 0x7adcacedf7f0>,
#   <matplotlib.patches.Wedge at 0x7adcacedfbb0>,
#   <matplotlib.patches.Wedge at 0x7adcacf18070>,
#   <matplotlib.patches.Wedge at 0x7adcacf184f0>,
#   <matplotlib.patches.Wedge at 0x7adcacf18970>,
#   <matplotlib.patches.Wedge at 0x7adcacf18df0>,
#   <matplotlib.patches.Wedge at 0x7adcacf19270>,
#   <matplotlib.patches.Wedge at 0x7adcacf196f0>,
#   <matplotlib.patches.Wedge at 0x7adcacf19b70>,
#   <matplotlib.patches.Wedge at 0x7adcacf19ff0>,
#   <matplotlib.patches.Wedge at 0x7adcacf1a470>,
#   <matplotlib.patches.Wedge at 0x7adcacf1a8f0>,
#   <matplotlib.patches.Wedge at 0x7adcacf1ad70>,
#   <matplotlib.patches.Wedge at 0x7adcacf1b1f0>,
#   <matplotlib.patches.Wedge at 0x7adcacf1b670>,
#   <matplotlib.patches.Wedge at 0x7adcacf1baf0>,
#   <matplotlib.patches.Wedge at 0x7adcacf1bf70>,
#   <matplotlib.patches.Wedge at 0x7adcacf4c430>,
#   <matplotlib.patches.Wedge at 0x7adcacf4c8b0>,
#   <matplotlib.patches.Wedge at 0x7adcacf4cd30>,
#   <matplotlib.patches.Wedge at 0x7adcacf4d1b0>,
#   <matplotlib.patches.Wedge at 0x7adcacf4d630>,
#   <matplotlib.patches.Wedge at 0x7adcacf4dab0>,
#   <matplotlib.patches.Wedge at 0x7adcacf4df30>,
#   <matplotlib.patches.Wedge at 0x7adcacf4e3b0>,
#   <matplotlib.patches.Wedge at 0x7adcacf4e830>,
#   <matplotlib.patches.Wedge at 0x7adcacf4ecb0>,
#   <matplotlib.patches.Wedge at 0x7adcacf4f130>,
#   <matplotlib.patches.Wedge at 0x7adcacf4f5b0>,
#   <matplotlib.patches.Wedge at 0x7adcacf4fa30>,
#   <matplotlib.patches.Wedge at 0x7adcacf4feb0>,
#   <matplotlib.patches.Wedge at 0x7adcacd8c370>,
#   <matplotlib.patches.Wedge at 0x7adcacd8c7f0>,
#   <matplotlib.patches.Wedge at 0x7adcacd8cc70>,
#   <matplotlib.patches.Wedge at 0x7adcacd8d0f0>,
#   <matplotlib.patches.Wedge at 0x7adcacd8d570>,
#   <matplotlib.patches.Wedge at 0x7adcacd8d9f0>,
#   <matplotlib.patches.Wedge at 0x7adcacd8de70>,
#   <matplotlib.patches.Wedge at 0x7adcacd8e2f0>,
#   <matplotlib.patches.Wedge at 0x7adcacd8e770>,
#   <matplotlib.patches.Wedge at 0x7adcacd8ebf0>,
# ...
#   Text(-0.8845175048832713, -1.9046335037363678, ''),
#   Text(-0.876359018320441, -1.908401129482068, ''),
#   Text(-0.8681844838738976, -1.9121338085920176, ''),
#   Text(-0.44877728872629585, -1.0042902693561633, ''),
#   Text(-0.8429163433393814, -1.9234063632346043, ''),
#   Text(-0.8312045060142068, -1.9284965826212082, ''),
#   Text(-0.8193530619572185, -1.9335616255659736, ''),
#   Text(-0.8068157958848798, -1.9388265191890295, ''),
#   Text(-0.4161476082807609, -1.0182441593852638, ''),
#   Text(-0.40948812271397944, -1.0209404866867515, ''),
#   Text(-0.770213314520469, -1.9536559190746443, ''),
#   Text(-0.7590906645879532, -1.9580044338395715, ''),
#   Text(-0.7490482331919665, -1.9618681771087463, ''),
#   Text(-0.3877256269661329, -1.0294021751452245, ''),
#   Text(-0.3812843688900432, -1.031805325650203, ''),
#   Text(-0.714914104444947, -1.9745626916524275, ''),
#   Text(-0.7014448723076757, -1.9793875545514752, ''),
#   Text(-0.36011705309348, -1.0393823685589763, ''),
#   Text(-0.6750811944145754, -1.9885334749376964, ''),
#   Text(-0.347097052020966, -1.0438024892087368, ''),
#   Text(-0.6506222887147857, -1.9966698869436414, ''),
#   Text(-0.6375672643523596, -2.0008768036603977, ''),
#   Text(-0.6252752466312761, -2.0047520709429874, ''),
#   Text(-0.32089639374101175, -1.0521527952175072, ''),
#   Text(-0.3128894621996071, -1.054561607704567, ''),
#   Text(-0.3044478559917434, -1.0570295658031665, ''),
#   Text(-0.2964639752661687, -1.0592965172081803, ''),
#   Text(-0.5536686305022733, -2.025697669346968, ''),
#   Text(-0.5417970792670187, -2.0289051049513698, ''),
#   Text(-0.5301357784858126, -2.0319832815181433, ''),
#   Text(-0.27163272863726334, -1.0659341727954288, ''),
#   Text(-0.5072200828015901, -2.037824277901004, ''),
#   Text(-0.49619752213473056, -2.0405362087028385, ''),
#   Text(-0.48435511959641786, -2.0433795824860197, ''),
#   Text(-0.2479808908060342, -1.0716834783624527, ''),
#   Text(-0.4623521226950644, -2.0484702864916953, ''),
#   Text(-0.45057976504355995, -2.051091873937706, ''),
#   Text(-0.43798308364954325, -2.0538185943351563, ''),
#   Text(-0.423401255847429, -2.056874176158284, ''),
#   Text(-0.40891409690311004, -2.059803209375574, ''),
#   Text(-0.3961486168384815, -2.0622963592502797, ''),
#   Text(-0.3849953986834636, -2.064407552542027, ''),
#   Text(-0.19648658530391366, -1.0823091156391542, ''),
#   Text(-0.3630049353247096, -2.0683876370085716, ''),
#   Text(-0.34890464378285196, -2.070812775107098, ''),
#   Text(-0.175548655638718, -1.085901777097468, ''),
#   Text(-0.32217517149409103, -2.075139310714525, ''),
#   Text(-0.30873159239823467, -2.07718193807265, ''),
#   Text(-0.29422141953855063, -2.0792868383858734, ''),
#   Text(-0.28204050896280214, -2.080974087129391, ''),
#   Text(-0.2700844502658673, -2.0825595765126588, ''),
#   Text(-0.2568286278025702, -2.084235844606135, ''),
#   Text(-0.12714966902651148, -1.092626634155716, ''),
#   Text(-0.22946360469636612, -2.0874257960750966, ''),
#   Text(-0.2161776429582578, -2.088843514168788, ''),
#   Text(-0.10608706870897562, -1.0948723824504558, ''),
#   Text(-0.190875324558624, -2.091307392631375, ''),
#   Text(-0.1776832657374639, -2.0924695116242127, ''),
#   Text(-0.162362228845568, -2.0937140460541164, ''),
#   Text(-0.07812910310192295, -1.097221875123026, ''),
#   Text(-0.07151724772169273, -1.097672666726431, ''),
#   Text(-0.12260691227469203, -2.096417788767894, ''),
#   Text(-0.057667484087447936, -1.0984873514424387, ''),
#   Text(-0.09769222051486645, -2.0977264430928253, ''),
#   Text(-0.04411798320882764, -1.0991149182672328, ''),
#   Text(-0.06992755695524905, -2.0988354239383016, ''),
#   Text(-0.05574482818979039, -2.099259992028165, ''),
#   Text(-0.042268868131863924, -2.099574562330867, ''),
#   Text(-0.027490615000920066, -2.0998200556445, ''),
#   Text(-0.01401164243275646, -2.0999532551645848, ''),
#   Text(-9.290531891169912e-05, -1.0999999960766373, ''),
#   Text(0.01306572010510005, -2.0999593536442878, ''),
#   Text(0.012170291156107965, -1.099932672490992, ''),
#   Text(0.018796839472851917, -1.0998393877406973, ''),
#   Text(0.0266610900107151, -1.0996768553895462, ''),
#   Text(0.03365728149787487, -1.0994849646094178, ''),
#   Text(0.07595428523240967, -2.098625966330073, ''),
#   Text(0.04671709999143077, -1.0990075125168122, ''),
#   Text(0.1026527527330622, -2.097489549999314, ''),
#   Text(0.11587796062370159, -2.0968004908053826, ''),
#   Text(0.06644844757929588, -1.097991167457326, ''),
#   Text(0.13606095217175995, -2.09558760668556, ''),
#   Text(0.14809404352246897, -2.094771623417017, ''),
#   Text(0.08510863192109255, -1.0967025671404804, ''),
#   Text(0.1766228739519952, -2.092559284798626, ''),
#   Text(0.1895800013177702, -2.091425213365363, ''),
#   Text(0.20241216464808587, -2.0902223124831667, ''),
#   Text(0.2167657038027608, -2.088782571177502, ''),
#   Text(0.2306389111323281, -2.087296263751673, ''),
#   Text(0.12776486157028413, -1.0925548682551034, ''),
#   Text(0.2584715143441173, -2.084032743570182, ''),
#   Text(0.27207775322748845, -2.0823000975360593, ''),
#   Text(0.28473520915488415, -2.0806070894495012, ''),
#   Text(0.2990207571350746, -2.078602075146267, ''),
#   Text(0.16447288702428114, -1.087634437407118, ''),
#   Text(0.32813281397336436, -2.0742055964619133, ''),
#   Text(0.34249002418850494, -2.071883342114454, ''),
#   Text(0.35450011960285843, -2.069862233386937, ''),
#   Text(0.19215825111627158, -1.0830859645143298, ''),
#   Text(0.38127514107166116, -2.0650978831040394, ''),
#   Text(0.3931290803550508, -2.0628740936322782, ''),
#   Text(0.4058981962263526, -2.0603996346097992, ''),
#   Text(0.42096885622918345, -2.057373379356575, ''),
#   Text(0.228147483582949, -1.0760802598945713, ''),
#   Text(0.4488472699193582, -2.0514716981440273, ''),
#   Text(0.24176150709353705, -1.073103617405077, ''),
#   Text(0.4743396026213935, -2.0457277290453337, ''),
#   Text(0.48700096314543573, -2.042750611772132, ''),
#   Text(0.49860995409573705, -2.0399480664165566, ''),
#   Text(0.5095145915685395, -2.0372517961653007, ''),
#   Text(0.2731929158030595, -1.0655353728314338, ''),
#   Text(0.5323093156629792, -2.0314149729827267, ''),
#   Text(0.5433962617666126, -2.0284773853060507, ''),
#   Text(0.2917491226840359, -1.0606047564541163, ''),
#   Text(0.570074732896279, -2.021141954171759, ''),
#   Text(0.5831499658924132, -2.017408267376655, ''),
#   Text(0.5967676109582665, -2.0134220666594382, ''),
#   Text(0.6112630544314339, -2.0090688087487583, ''),
#   Text(0.6242592486090915, -2.0050686747655337, ''),
#   Text(0.6340737909495311, -2.0019866202427252, ''),
#   Text(0.3380331762815868, -1.0467729322699273, ''),
#   Text(0.6587114796041912, -1.9940158441290423, ''),
#   Text(0.3522647339562226, -1.0420698427700286, ''),
#   Text(0.6861553151230033, -1.984739500168335, ''),
#   Text(0.6988809027408892, -1.980294292216205, ''),
#   Text(0.7116889413413746, -1.9757274231969333, ''),
#   Text(0.38000594668332344, -1.0322768429473324, ''),
#   Text(0.7371042447894962, -1.9663868724931284, ''),
#   Text(0.748053952690517, -1.9622475083088, ''),
#   Text(0.75920091127948, -1.957961689184037, ''),
#   Text(0.7699933053308938, -1.95374264163569, ''),
#   Text(0.7815305594649493, -1.9491562237600157, ''),
#   Text(0.7934784248015394, -1.9443230156983866, ''),
#   Text(0.8072524462331949, -1.938644755505898, ''),
#   Text(0.820659328512826, -1.9330075702192369, ''),
#   Text(0.8312045063668612, -1.9284965824692102, ''),
#   Text(0.8410748695374031, -1.9242123229603953, ''),
#   Text(0.44634443055102935, -1.0053738853362353, ''),
#   Text(0.8634445819772327, -1.9142788338834449, ''),
#   Text(0.8745318915332665, -1.9092391077838438, ''),
#   Text(0.8854825710456729, -1.904185026822327, ''),
#   Text(0.8984351792291084, -1.8981080656073197, ''),
#   Text(0.47647876122262917, -0.9914474217545522, ''),
#   Text(0.9195401280469606, -1.8879740339611082, ''),
#   Text(0.9319576810628507, -1.8818753626922144, ''),
#   Text(0.944546008130541, -1.875588664532994, ''),
#   Text(0.9567761712264562, -1.869379404554689, ''),
#   Text(0.5061791322575382, -0.9766179836901459, ''),
#   Text(0.9764058783313729, -1.8592018612189318, ''),
#   Text(0.5179644836447119, -0.9704188753742722, ''),
#   Text(1.0002967299610153, -1.8464578121444584, ''),
#   Text(1.0117138002935664, -1.840226938802807, ''),
#   Text(1.0215427802063548, -1.8347889110762228, ''),
#   Text(1.03072446978776, -1.8296467056185302, ''),
#   Text(1.0429606284945698, -1.8226994067619082, ''),
#   Text(1.0564787107026876, -1.8148974444392132, ''),
#   Text(1.0678010478539939, -1.8082590860277499, ''),
#   Text(0.565392652801591, -0.9435736050557898, ''),
#   Text(1.0906233043052183, -1.7945865284533837, ''),
#   Text(0.5771427793078489, -0.9364327056936936, ''),
#   Text(1.1137717738607125, -1.780312454529025, ''),
#   Text(1.1240779376993804, -1.773823212718085, ''),
#   Text(1.135639595890808, -1.7664435196872166, ''),
#   Text(1.1478460090859979, -1.7585361922421008, ''),
#   Text(1.1588143081996396, -1.7513278959440437, ''),
#   Text(1.1697373417873513, -1.7440511893944688, ''),
#   Text(0.6188269263065239, -0.9094246726793924, ''),
#   Text(1.1912511613987906, -1.729427844827888, ''),
#   Text(1.1992233619475452, -1.7239093155265528, ''),
#   Text(1.20862087128551, -1.7173338608124675, ''),
#   Text(1.21942673851644, -1.7096778729898676, ''),
#   Text(0.6439805136496672, -0.8917898284010145, ''),
#   Text(1.2377425005727805, -1.6964650017833676, ''),
#   Text(1.2475603075828476, -1.689258203752106, ''),
#   Text(1.2590402226847606, -1.6807194047972165, ''),
#   Text(1.2699908990815065, -1.6724601987043362, ''),
#   Text(1.2811684805479115, -1.663913256287886, ''),
#   Text(1.2924749412298184, -1.655146074004641, ''),
#   Text(0.6820759358325139, -0.8630019801589105, ''),
#   Text(1.311123890658842, -1.6404127966288304, ''),
#   Text(1.3215345338678457, -1.632037522790054, ''),
#   Text(1.3321659140570605, -1.6233711767259256, ''),
#   Text(1.3425586281920405, -1.6147867753567673, ''),
#   Text(1.3528960263378562, -1.6061358416769234, ''),
#   Text(1.3623680090988626, -1.5981093228512253, ''),
#   Text(1.372955869360923, -1.5890223978243327, ''),
#   Text(1.3842835474189363, -1.5791640384536516, ''),
#   Text(1.3947450509741568, -1.5699319229772661, ''),
#   Text(1.405144984912448, -1.5606305044357542, ''),
#   Text(0.7413976652826798, -0.8126066095678719, ''),
#   Text(0.7470076581481824, -0.8074525117107311, ''),
#   Text(0.7523559312211613, -0.8024715276920045, ''),
#   Text(0.7577158928115942, -0.7974124564996015, ''),
#   Text(1.456631062313944, -1.5126883182936766, ''),
#   Text(1.4656334463896155, -1.5039676196062528, ''),
#   Text(1.4743310353582804, -1.4954424088474223, ''),
#   Text(0.7772369503288281, -0.7783975353529473, ''),
#   Text(1.4939058506847047, -1.4758879731504044, ''),
#   Text(1.5031008610108012, -1.4665223495155428, ''),
#   Text(0.7913932853700109, -0.7640004370883964, ''),
#   Text(1.5191118648376647, -1.4499307370041623, ''),
#   Text(1.528873888293197, -1.4396335067284456, ''),
#   Text(0.8051985904567454, -0.7494366083442086, ''),
#   Text(0.8095733279964695, -0.7447086857266544, ''),
#   Text(1.5551993257815053, -1.4111538034844933, ''),
#   Text(1.5642252555751104, -1.4011421590334723, ''),
#   Text(1.5735783029081332, -1.3906298301908957, ''),
#   Text(1.5818501102099867, -1.3812133176409258, ''),
#   Text(0.8323248204914034, -0.7191907905374993, ''),
#   Text(1.5976106083556616, -1.362952803316921, ''),
#   Text(1.6061739332522427, -1.352850803356017, ''),
#   Text(1.613765792750587, -1.3437856846045313, ''),
#   Text(0.8495706101260008, -0.6987344119264021, ''),
#   Text(1.6288704185114748, -1.3254362148735237, ''),
#   Text(1.6348242729218962, -1.3180855801750484, ''),
#   Text(1.6430302780027657, -1.3078423091359885, ''),
#   Text(1.6512451601187959, -1.297454978480661, ''),
#   Text(1.6593219047900092, -1.2871094810792343, ''),
#   Text(1.6674057172311478, -1.2766198236534172, ''),
#   Text(1.674995395869452, -1.2666453425549464, ''),
#   Text(1.6818883916272396, -1.2574782058189071, ''),
#   Text(1.6873244408284893, -1.2501744803757697, ''),
#   Text(1.6941272945539931, -1.240940252327713, ''),
#   Text(1.7012262970127963, -1.2311901097524007, ''),
#   Text(1.707994053903055, -1.2217840692331066, ''),
#   Text(0.8987887725548838, -0.6341756399683651, ''),
#   Text(1.7238755562453592, -1.1992718901816026, ''),
#   Text(1.731337245746428, -1.1884743756140361, ''),
#   Text(1.7377360709828187, -1.1790985317628024, ''),
#   Text(1.7440841230339474, -1.1696882370020258, ''),
#   Text(1.7515562335652302, -1.1584691453201441, ''),
#   Text(1.7596663771582022, -1.1461126650983875, ''),
#   Text(1.7664115505042788, -1.1356893211812245, ''),
#   Text(0.928299131892975, -0.5901361891349735, ''),
#   Text(1.7778309313358176, -1.117728580463799, ''),
#   Text(1.7828476629847267, -1.1097090657419626, ''),
#   Text(1.7889438496557777, -1.099854491639129, ''),
#   Text(1.7950469352667373, -1.089865358743682, ''),
#   Text(1.8015804743050956, -1.07903095164255, ''),
#   Text(1.808649770502237, -1.0671391697722492, ''),
#   Text(0.9505826594318375, -0.5535274226156238, ''),
#   Text(0.953869401347527, -0.5478441066333659, ''),
#   Text(0.957213728203632, -0.541979592363498, ''),
#   Text(0.9608840044465432, -0.5354455434484217, ''),
#   Text(1.842075239619716, -1.008344589701341, ''),
#   Text(0.9687661745039934, -0.5210490371710693, ''),
#   Text(1.8562521361900672, -0.9820020401658096, ''),
#   Text(0.9758616234981937, -0.5076357865472745, ''),
#   Text(0.9792974834705505, -0.5009754872927887, ''),
#   Text(1.876199884497645, -0.9433313274830977, ''),
#   Text(1.8828974884799896, -0.9298908795529439, ''),
#   Text(1.889343987346233, -0.9167220393765154, ''),
#   Text(0.9931180679601016, -0.47298678955251505, ''),
#   Text(0.99618617337831, -0.46649020136534475, ''),
#   Text(0.9987710358937287, -0.46092994897247497, ''),
#   Text(1.001299223075089, -0.4554117542062603, ''),
#   Text(1.917160804936131, -0.8570265153521481, ''),
#   Text(1.0070131822510957, -0.44263354004472116, ''),
#   Text(1.9271602506988597, -0.8342981290439939, ''),
#   Text(1.0122734547491237, -0.4304677140161317, ''),
#   Text(1.015492491194515, -0.42281792810565416, ''),
#   Text(1.0183495697866218, -0.41588959317997193, ''),
#   Text(1.0209058989806223, -0.4095743466412021, ''),
#   Text(1.9538076693736186, -0.7698282867606445, ''),
#   Text(1.0258786217508544, -0.39695472466588383, ''),
#   Text(1.0281194645038838, -0.39111426298237634, ''),
#   Text(1.0307386250269766, -0.3841586740885826, ''),
#   Text(1.9732511350009267, -0.7185262404516315, ''),
#   Text(1.0360855536017373, -0.3694952308457875, ''),
#   Text(1.9824296062204487, -0.6928007335306716, ''),
#   Text(1.9864908634815637, -0.6810683147117269, ''),
#   Text(1.989916682572316, -0.6709929928251035, ''),
#   Text(1.9932914008068119, -0.6609004399072658, ''),
#   Text(1.9971273191291545, -0.6492168136978561, ''),
#   Text(2.00085885592048, -0.6376235869888979, ''),
#   Text(2.004205605389889, -0.6270246337455558, ''),
#   Text(2.0070792626184835, -0.6177643835369966, ''),
#   Text(1.0531683344150022, -0.31754757027181035, ''),
#   Text(2.0144773508897833, -0.5931955855804069, ''),
#   Text(2.0176543503338817, -0.582297967177254, ''),
#   Text(2.0205470348414947, -0.5721797619570664, ''),
#   Text(2.0237998426438852, -0.5605659612521843, ''),
#   Text(2.026800331400218, -0.5496184282172188, ''),
#   Text(1.063356681675093, -0.2815538448271218, ''),
#   Text(2.033954047571809, -0.5225236189554071, ''),
#   Text(2.037524048845701, -0.508424773565786, ''),
#   Text(2.0409406445062306, -0.4945313797955526, ''),
#   Text(1.0707474421410306, -0.2519918950054558, ''),
#   Text(2.047147332696008, -0.46817496540889647, ''),
#   Text(2.050187131850665, -0.4546787045749388, ''),
#   Text(1.0756350411348974, -0.23023739549153951, ''),
#   Text(2.056575668407221, -0.4248488203059899, ''),
#   Text(2.059306679472962, -0.41140734057384465, ''),
#   Text(1.0799984806004677, -0.20881398875717438, ''),
#   Text(2.063874490543104, -0.3878428641672325, ''),
#   Text(2.066067903828922, -0.37598326660632836, ''),
#   Text(2.0682136674755953, -0.3639948154399304, ''),
#   Text(1.0844063897929264, -0.18456105162322828, ''),
#   Text(2.072372955606059, -0.33951484926672715, ''),
#   Text(2.074177876430315, -0.3283079909582292, ''),
#   Text(2.0761537416774916, -0.3155719266958841, ''),
#   ...])

# %%
x = df['age']

# %%
print(x)
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
plt.hist(x)
plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')

# %%
x = df['age']

# %%
print(x)
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
q =sns.countplot(x)
q.set(xlabel="age")
# Out:
# [Text(0.5, 0, 'age')]

# %%
x = df['sex']
y = df['age']
sns.lineplot(x)
# Out:
# <Axes: ylabel='sex'>

# %%
x = df['target']

# %%
sns.countplot(x = "target" , data = df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
sns.barplot(x = df["age"], y=df["target"])
# Out:
# <Axes: xlabel='age', ylabel='target'>

# %%
sns.pairplot(df, hue='target')

# %%
sns.scatterplot(x=df["age"], y=df['target'])
# Out:
# <Axes: xlabel='age', ylabel='target'>

# %%
sns.distplot(x=df["age"])
# Out:
# <ipython-input-29-a663b7301403>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df["age"])
# <Axes: ylabel='Density'>

# %%
sns.boxplot(x=df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
df.isnull()
# Out:
#         age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0     False  False  False     False  False  False    False    False  False
# 1     False  False  False     False  False  False    False    False  False
# 2     False  False  False     False  False  False    False    False  False
# 3     False  False  False     False  False  False    False    False  False
# 4     False  False  False     False  False  False    False    False  False
# ...     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 1020  False  False  False     False  False  False    False    False  False
# 1021  False  False  False     False  False  False    False    False  False
# 1022  False  False  False     False  False  False    False    False  False
# 1023  False  False  False     False  False  False    False    False  False
# 1024  False  False  False     False  False  False    False    False  False
#
#       oldpeak  slope     ca   thal  target
# 0       False  False  False  False   False
# 1       False  False  False  False   False
# 2       False  False  False  False   False
# 3       False  False  False  False   False
# 4       False  False  False  False   False
# ...       ...    ...    ...    ...     ...
# 1020    False  False  False  False   False
# 1021    False  False  False  False   False
# 1022    False  False  False  False   False
# 1023    False  False  False  False   False
# 1024    False  False  False  False   False
#
# [1025 rows x 14 columns]

# %%
x = df.drop('target', axis=1)

# %%
y = df['target']

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.5, random_state=0)

# %%
print(x)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# 2         0   0     3
# 3         2   1     3
# 4         1   3     2
# ...     ...  ..   ...
# 1020      2   0     2
# 1021      1   1     3
# 1022      1   1     2
# 1023      2   0     2
# 1024      1   1     3
#
# [1025 rows x 13 columns]

# %%
x_train.shape
# Out:
# (512, 13)

# %%
y_train.shape
# Out:
# (512,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
a = StandardScaler()

# %%
x_train = a.fit_transform(x_train)

# %%
print(x_train)
# Out:
# [[-1.51999569  0.66196846  1.05084285 ... -0.72488544 -0.74511006
#   -0.51851712]
#  [-1.406781    0.66196846  2.01333219 ...  0.98544335  1.16715234
#   -0.51851712]
#  [-0.27463408  0.66196846  0.08835351 ...  0.98544335  0.21102114
#   -0.51851712]
#  ...
#  [ 1.19715692  0.66196846  2.01333219 ... -0.72488544  0.21102114
#   -0.51851712]
#  [ 1.42358631  0.66196846 -0.87413582 ... -0.72488544 -0.74511006
#   -0.51851712]
#  [ 0.63108346  0.66196846  1.05084285 ... -0.72488544 -0.74511006
#   -0.51851712]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = clf.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_predict, y_test)
# Out:
# 0.4697855750487329

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_predict, y_test)
# Out:
# array([[241, 272],
#        [  0,   0]])

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
graphviz.Source(export_graphviz(clf,feature_names = x.columns,filled = True))
